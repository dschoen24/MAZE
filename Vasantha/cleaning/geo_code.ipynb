# %%
import pandas as pd
import requests


# Import API key
from api_keys import g_key

# %%
clean_museums_df = pd.read_csv('museums_new.csv',low_memory=False)
clean_museums_df.columns
# Out:
# Index(['Museum_ID', 'Museum_Name', 'Legal_Name', 'Museum_Type',
#        'Street_Add_AdmLoc', 'City_AdmLoc', 'State_AdmLoc', 'Zip_AdmLoc',
#        'Street_Add_PhyLoc', 'City_PhyLoc', 'State_PhyLoc', 'Zip_PhyLoc',
#        'Phone_Number', 'Latitude', 'Longitude', 'Locale_Code_NCES',
#        'FIPS_County', 'FIPS_State', 'Region_Code_AAM', 'Employer_ID',
#        'Tax_Period', 'Income', 'Revenue'],
#       dtype='object')

# %%
clean_museums_df.dtypes
# Out:
# Museum_ID              int64
# Museum_Name           object
# Legal_Name            object
# Museum_Type           object
# Street_Add_AdmLoc     object
# City_AdmLoc           object
# State_AdmLoc          object
# Zip_AdmLoc            object
# Street_Add_PhyLoc     object
# City_PhyLoc           object
# State_PhyLoc          object
# Zip_PhyLoc           float64
# Phone_Number          object
# Latitude             float64
# Longitude            float64
# Locale_Code_NCES     float64
# FIPS_County           object
# FIPS_State           float64
# Region_Code_AAM        int64
# Employer_ID           object
# Tax_Period           float64
# Income               float64
# Revenue              float64
# dtype: object

# %%
Null_StAddPLoc= clean_museums_df[clean_museums_df['Street_Add_PhyLoc'].isna()]


clean_museums_df['Street_Add_PhyLoc'] = clean_museums_df['Street_Add_PhyLoc'].fillna('NoStreetM') 


#Null_StAddPLoc

# %%
Null_StAddPLoc= clean_museums_df[clean_museums_df['City_PhyLoc'].isna() & clean_museums_df['State_PhyLoc'].isna()& clean_museums_df['Zip_PhyLoc'].isna()]
#Null_StAddPLoc

# %%
# Google geocode is fetching multiple addresses .. it is safe to just use the admin address for these records

# %%
for index, row in clean_museums_df.iterrows():
    # print(type(row['Street_Add_PhyLoc']))
    if(row['Street_Add_PhyLoc']=='NoStreetM'):
        # print(f'index: {index}')
        # print(row['Museum_Name'])
        # print(row['Street_Add_AdmLoc'],row['City_AdmLoc'],row['State_AdmLoc'],row['Zip_AdmLoc'],)

        Street_Add_PhyLoc   = row['Street_Add_AdmLoc']
        City_PhyLoc         = row['City_AdmLoc']
        State_PhyLoc        = row['State_AdmLoc']
        Zip_PhyLoc          = row['Zip_AdmLoc']    


        
        #print (f'this : {Street_Add_PhyLoc} {City_PhyLoc} {State_PhyLoc} {Zip_PhyLoc}')
        
        clean_museums_df.loc[index, "Street_Add_PhyLoc"] = Street_Add_PhyLoc
        clean_museums_df.loc[index, "City_PhyLoc"] = City_PhyLoc
        clean_museums_df.loc[index, "State_PhyLoc"] = State_PhyLoc
        clean_museums_df.loc[index, "Zip_PhyLoc"] = Zip_PhyLoc

# %%
Null_StAddPLoc= clean_museums_df[clean_museums_df['Street_Add_PhyLoc'].isna()]
Null_StAddPLoc
# Out:
#         Museum_ID                                        Museum_Name  \
# 2086   8409400157  ELKHORN SLOUGH NATIONAL ESTUARINE RESEARCH RES...
# 5477   8409400143       DELAWARE NATIONAL ESTUARINE RESEARCH RESERVE
# 5616   8409400050   APALACHICOLA NATIONAL ESTUARINE RESEARCH RESERVE
# 7270   8409400590  SAPELO ISLAND NATIONAL ESTUARINE RESEARCH RESERVE
# 12117  8409400154                       EAST TAUNTON BEER CAN MUSEUM
# 16524  8409400221      GRAND BAY NATIONAL ESTUARINE RESEARCH RESERVE
# 21588  8409400546       PEALE'S BARBER FARM MASTODON EXHUMATION SITE
# 26525  8409400022      ACE BASIN NATIONAL ESTUARINE RESEARCH RESERVE
# 26776  8409400517  NORTH INLET-WINYAH BAY NATIONAL ESTUARINE RESE...
#
#                                               Legal_Name  \
# 2086   ELKHORN SLOUGH NATIONAL ESTUARINE RESEARCH RES...
# 5477        DELAWARE NATIONAL ESTUARINE RESEARCH RESERVE
# 5616    APALACHICOLA NATIONAL ESTUARINE RESEARCH RESERVE
# ...

# %%
clean_museums_df.to_csv('museums_clean.csv', index=False)

# %%
# Config information.
url = "https://maps.googleapis.com/maps/api/geocode/json?latlng=" #40.714224,-73.961452&key=YOUR_API_KEY"

#Updated the table and added a new fiels for unit_of_measure in Nanograms
for index, row in clean_museums_df.iterrows():
    print(type(row['Street_Add_PhyLoc']))
    if(row['Street_Add_PhyLoc']=='NoStreet'):
        print(f'index: {index}')
        print(row['Museum_Name'])
        print(row['Street_Add_AdmLoc'],row['City_AdmLoc'],row['State_AdmLoc'],row['Zip_AdmLoc'],)
        
        lat = row['Latitude']
        lon = row['Longitude']
        end_point = (f'{url}{lat},{lon}&key={g_key}')
        #print(end_point)
        response = requests.get(end_point).json()
        # print (response)

        print(f"{index}:{row['Street_Add_PhyLoc']}")

        # Addr = (response['results'][0]['address_components'])
        # if (len(Addr)<7):
        #     Addr = (response['results'][1]['address_components'])
        #     Street_Add_PhyLoc = f"{Addr[1]['long_name']} {Addr[2]['short_name']}"
        #     City_PhyLoc = Addr[3]['long_name']
        #     State_PhyLoc = Addr[5]['short_name']
        #     Zip_PhyLoc = Addr[7]['long_name']
        # else:
        #     Street_Add_PhyLoc = f"{Addr[0]['long_name']} {Addr[1]['short_name']}"
        #     City_PhyLoc = Addr[3]['long_name']
        #     State_PhyLoc = Addr[5]['short_name']
        #     Zip_PhyLoc = Addr[7]['long_name']    


        print (response['results'][0]['formatted_address'])
        print (f'this : {Street_Add_PhyLoc} {City_PhyLoc} {State_PhyLoc} {Zip_PhyLoc}')
        
        # clean_museums_df.loc[index, "Street_Add_PhyLoc"] = Street_Add_PhyLoc
        # clean_museums_df.loc[index, "City_PhyLoc"] = City_PhyLoc
        # clean_museums_df.loc[index, "State_PhyLoc"] = State_PhyLoc
        # clean_museums_df.loc[index, "Zip_PhyLoc"] = Zip_PhyLoc
        break
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# index: 3
# ALASKA EDUCATORS HISTORICAL SOCIETY
# 214 BIRCH STREET KENAI AK 99611
# 3:NoStreetMunda
# 1216 2nd Ave, Kenai, AK 99611, USA
# this : 1216 2nd Ave Kenai Peninsula Borough US 7804

# %%
clean_museums_df = pd.read_csv('museums_clean.csv',low_memory=False)
clean_museums_df.columns
# Out:
# Index(['Museum_ID', 'Museum_Name', 'Legal_Name', 'Museum_Type',
#        'Street_Add_AdmLoc', 'City_AdmLoc', 'State_AdmLoc', 'Zip_AdmLoc',
#        'Street_Add_PhyLoc', 'City_PhyLoc', 'State_PhyLoc', 'Zip_PhyLoc',
#        'Phone_Number', 'Latitude', 'Longitude', 'Locale_Code_NCES',
#        'FIPS_County', 'FIPS_State', 'Region_Code_AAM', 'Employer_ID',
#        'Tax_Period', 'Income', 'Revenue'],
#       dtype='object')

# %%
# Next County Code (FIPS)
Null_CountyFips= clean_museums_df[clean_museums_df['FIPS_County'].isna()]
#Null_CountyFips

# 2536 found . we will add it to transform and get the countys based on lat long and add them

# %%
Null_CountyFips= clean_museums_df[clean_museums_df['FIPS_County'].isna()]
clean_museums_df['FIPS_County'] = clean_museums_df['FIPS_County'].fillna('99099') 
# Null_CountyFips

# %%
#  https://geo.fcc.gov/api/census/block/find?latitude=59.24675&longitude=-135.47365&format=json
# Config information.
url = "https://geo.fcc.gov/api/census/block/find?latitude=" #59.24675&longitude=-135.47365&format=json"

#Updated the table and added a new fiels for unit_of_measure in Nanograms
for index, row in clean_museums_df.iterrows():
    if(row['FIPS_County']=='99099'):
        # print(f'index: {index}')
        # print(row['Museum_Name'])
        
        lat = row['Latitude']
        lon = row['Longitude']

        end_point = (f'{url}{lat}&longitude={lon}&format=json')
        #print(end_point)
        try:
            response = requests.get(end_point).json()
            # print (response)
            # print (response['County']['FIPS'])
            fips_county = response['County']['FIPS']
            clean_museums_df.loc[index, "FIPS_County"] = fips_county
        except:
            print(response)
# Out:
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# {'status': 'error', 'statusCode': '400', 'statusMessage': 'invalid lat value'}
# ...

# %%
st = {'Block': {'FIPS': '020200003001110', 'bbox': [-149.69107, 61.252543, -149.683445, 61.253781]}, 'County': {'FIPS': '02020', 'name': 'Anchorage'}, 'State': {'FIPS': '02', 'code': 'AK', 'name': 'Alaska'}, 'status': 'OK', 'executionTime': '0'}
print (st['County']['FIPS'])
# Out:
# 02020

# %%
clean_museums_df
# Out:
#         Museum_ID                                        Museum_Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# ...           ...                                                ...
# 33066  8405600184                   WYOMING STATE HISTORICAL SOCIETY
# 33067  8405600061                               WYOMING STATE MUSEUM
# 33068  8405600158      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33069  8405600137                      WYOMING TRANSPORTATION MUSEUM
# 33070  8405600199                          YELLOWSTONE NATIONAL PARK
#
#                                               Legal_Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM
# ...

# %%
Null_CountyFips= clean_museums_df[clean_museums_df['FIPS_County'] == '99099']
Null_CountyFips
# Out:
#         Museum_ID                                        Museum_Name  \
# 644    8400500216                     ARKANSAS NATIONAL GUARD MUSEUM
# 1838   8409502039                         CHICO UNIVERSITY ARBORETUM
# 2086   8409400157  ELKHORN SLOUGH NATIONAL ESTUARINE RESEARCH RES...
# 2485   8400602669                          IRVINE HISTORICAL SOCIETY
# 2495   8409501554                          JANET TURNER PRINT MUSEUM
# 2901   8400600236                             MUSEUM OF ANTHROPOLOGY
# 2904   8409501135                             MUSEUM OF ANTHROPOLOGY
# 3397   8409500848                                   ROTH PLANETARIUM
# 4739   8400900111  ASSOCIATION FOR PRESERVATION TECHNOLOGY NORTHEAST
# 4832   8400900526                    CRYSTAL LAKE HISTORICAL SOCIETY
# 5121   8400900532                                            PROMARE
# 5477   8409400143       DELAWARE NATIONAL ESTUARINE RESEARCH RESERVE
# 5616   8409400050   APALACHICOLA NATIONAL ESTUARINE RESEARCH RESERVE
# ...

# %%
# clean_museums_df_no_lat_longs ####https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=YOUR_API_KEY
clean_museums_df_no_lat_longs = clean_museums_df[(clean_museums_df['Latitude'].isna()) & (clean_museums_df['Longitude'].isna()) ]
clean_museums_df_no_lat_longs
# Out:
#         Museum_ID                                        Museum_Name  \
# 644    8400500216                     ARKANSAS NATIONAL GUARD MUSEUM
# 1838   8409502039                         CHICO UNIVERSITY ARBORETUM
# 2086   8409400157  ELKHORN SLOUGH NATIONAL ESTUARINE RESEARCH RES...
# 2485   8400602669                          IRVINE HISTORICAL SOCIETY
# 2495   8409501554                          JANET TURNER PRINT MUSEUM
# ...           ...                                                ...
# 27827  8404801951                         BARRETT HISTORICAL SOCIETY
# 28886  8404800713                              NATIONAL BIBLE MUSEUM
# 29907  8405100847                                       CENTER HOUSE
# 30685  8405100008                              WARRENTON ANTIQUARIAN
# 32901  8404000101                           CHEROKEE HERITAGE CENTER
#
#                                               Legal_Name  \
# 644          ARKANSAS NATIONAL GUARD MUSEUM INCORPORATED
# ...

# %%
clean_museums_df['Latitude'] = clean_museums_df['Latitude'].fillna(0) 
clean_museums_df['Longitude'] = clean_museums_df['Longitude'].fillna(0)

# %%
# Config information.
url = "https://maps.googleapis.com/maps/api/geocode/json?address="
# 1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=YOUR_API_KEY"


#Updated the table and added a new fiels for unit_of_measure in Nanograms
for index, row in clean_museums_df.iterrows():
    if(row['Latitude']==0):
        
        print(row['Street_Add_PhyLoc'],row['City_PhyLoc'],row['State_PhyLoc'],row['Zip_PhyLoc'],)
        
        Street_Add_PhyLoc = row['Street_Add_PhyLoc']
        City_PhyLoc = row['City_PhyLoc']
        State_PhyLoc = row['State_PhyLoc']

        endstr = str(Street_Add_PhyLoc).replace(" ","+")
        endstr = endstr+",+"+City_PhyLoc.replace(" ","+")
        endstr = endstr+",+"+State_PhyLoc+"&key="

        end_point = (f'{url}{endstr}{g_key}')
        print(end_point)
        response = requests.get(end_point).json()
        # print (response)

        lat = response['results'][0]['geometry']['location']['lat']
        lng = response['results'][0]['geometry']['location']['lng']

        clean_museums_df.loc[index, "Latitude"]  = lat
        clean_museums_df.loc[index, "Longitude"] = lng

        # clean_museums_df.loc[index, "State_PhyLoc"] = State_PhyLoc
        # clean_museums_df.loc[index, "Zip_PhyLoc"] = Zip_PhyLoc
        # break
# Out:
# nan ELKHORN CA 95039.0
# https://maps.googleapis.com/maps/api/geocode/json?address=nan,+ELKHORN,+CA&key=AIzaSyCR_UvTdJZscmEMJdTn-PGjFBuEj4MVFfI
# 5 RANCHO SAN JOAQUIN IRVINE CA 92715.0
# https://maps.googleapis.com/maps/api/geocode/json?address=5+RANCHO+SAN+JOAQUIN,+IRVINE,+CA&key=AIzaSyCR_UvTdJZscmEMJdTn-PGjFBuEj4MVFfI
# 400 WEST 1ST STREET CHICO CA 95929.0
# https://maps.googleapis.com/maps/api/geocode/json?address=400+WEST+1ST+STREET,+CHICO,+CA&key=AIzaSyCR_UvTdJZscmEMJdTn-PGjFBuEj4MVFfI
# CALIFORNIA STATE UNIVERSITY CHICO CHICO CA 95929.0
# https://maps.googleapis.com/maps/api/geocode/json?address=CALIFORNIA+STATE+UNIVERSITY+CHICO,+CHICO,+CA&key=AIzaSyCR_UvTdJZscmEMJdTn-PGjFBuEj4MVFfI
# 400 WEST 1ST STREET CHICO CA 95926.0
# https://maps.googleapis.com/maps/api/geocode/json?address=400+WEST+1ST+STREET,+CHICO,+CA&key=AIzaSyCR_UvTdJZscmEMJdTn-PGjFBuEj4MVFfI
# 400 WEST 1ST STREET CHICO CA 95929.0
# ...

# %%
srt = {'results': [{'address_components': [{'long_name': 'Camp Robinson Road', 'short_name': 'Camp Robinson Rd', 'types': ['route']}, {'long_name': 'North Little Rock', 'short_name': 'North Little Rock', 'types': ['locality', 'political']}, {'long_name': 'Pulaski County', 'short_name': 'Pulaski County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Arkansas', 'short_name': 'AR', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Camp Robinson Rd, North Little Rock, AR, USA', 'geometry': {'bounds': {'northeast': {'lat': 34.824342, 'lng': -92.2655982}, 'southwest': {'lat': 34.7869666, 'lng': -92.27815199999999}}, 'location': {'lat': 34.8054346, 'lng': -92.26592169999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 34.824342, 'lng': -92.2655982}, 'southwest': {'lat': 34.7869666, 'lng': -92.27815199999999}}}, 'place_id': 'EixDYW1wIFJvYmluc29uIFJkLCBOb3J0aCBMaXR0bGUgUm9jaywgQVIsIFVTQSIuKiwKFAoSCQ2mbCEFvdKHEXBiyx98bJAEEhQKEglTkF2g6JnShxGh2XtaS813Zg', 'types': ['route']}], 'status': 'OK'}
print(srt['results'][0]['geometry']['location'])
# Out:
# {'lat': 34.8054346, 'lng': -92.26592169999999}

# %%
clean_museums_df_no_lat_longs = clean_museums_df[(clean_museums_df['Latitude'].isna()) & (clean_museums_df['Longitude'].isna()) ]
clean_museums_df_no_lat_longs
# Out:
# Empty DataFrame
# Columns: [Museum_ID, Museum_Name, Legal_Name, Museum_Type, Street_Add_AdmLoc, City_AdmLoc, State_AdmLoc, Zip_AdmLoc, Street_Add_PhyLoc, City_PhyLoc, State_PhyLoc, Zip_PhyLoc, Phone_Number, Latitude, Longitude, Locale_Code_NCES, FIPS_County, FIPS_State, Region_Code_AAM, Employer_ID, Tax_Period, Income, Revenue]
# Index: []
#
# [0 rows x 23 columns]

# %%
clean_museums_df
# Out:
#         Museum_ID                                        Museum_Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# ...           ...                                                ...
# 33066  8405600184                   WYOMING STATE HISTORICAL SOCIETY
# 33067  8405600061                               WYOMING STATE MUSEUM
# 33068  8405600158      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33069  8405600137                      WYOMING TRANSPORTATION MUSEUM
# 33070  8405600199                          YELLOWSTONE NATIONAL PARK
#
#                                               Legal_Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM
# ...

# %%
clean_museums_df.to_csv('museum_final.csv', index=False)

# %%
clean_museums_df.loc[clean_museums_df['State_AdmLoc'] != clean_museums_df['State_PhyLoc']]
# Out:
#         Museum_ID                                   Museum_Name  \
# 230    8400100211            ATCHISON COUNTY HISTORICAL SOCIETY
# 537    8400100170            RANDOLPH COUNTY HISTORICAL SOCIETY
# 890    8400500130  SCOTT COUNTY HISTORICAL GENEALOGICAL SOCIETY
# 1284   8400400220         SAWTOOTH MOUNTAINS HISTORICAL SOCIETY
# 2373   8400601936                  HISTORIC SAN ANTONIO MISSION
# ...           ...                                           ...
# 30670  8405100987      VIRGINIA TRUST FOR HISTORIC PRESERVATION
# 30938  8405000244                 SHREWSBURY HISTORICAL SOCIETY
# 31866  8405500331    CHICAGO & NORTH WESTERN HISTORICAL SOCIETY
# 31909  8405500776                                   CSTEA HOUSE
# 32010  8405500235                     GENEVA HISTORICAL SOCIETY
#
#                                        Legal_Name            Museum_Type  \
# 230            ATCHISON COUNTY HISTORICAL SOCIETY  HISTORIC PRESERVATION
# ...
