# %%
import os
import pandas as pd

# %% [markdown]
# # Transform

# %%
museums_df = pd.read_csv('Data/museums.csv')
museums_df = museums_df.drop(columns=["Alternate Name", "Institution Name"])
museums_df.head()
# Out:
# C:\Users\SMKazmi\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (9,14,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Museum ID                                        Museum Name  \
# 0  8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1  8400200117                            ALASKA BOTANICAL GARDEN
# 2  8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3  8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4  8400200027                             ALASKA HERITAGE MUSEUM
#
#                                           Legal Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM
# 1                        ALASKA BOTANICAL GARDEN INC
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3                ALASKA EDUCATORS HISTORICAL SOCIETY
# ...

# %%
museums_df.dropna(how="any")
# Out:
#         Museum ID                                   Museum Name  \
# 6      8400200078                          ALASKA JEWISH MUSEUM
# 8      8400200107  ALASKA MASONIC LIBRARY AND MUSEUM FOUNDATION
# 19     8400200087                                    ALASKA ZOO
# 22     8400200152                    ALUTIIQ HERITAGE ENDOWMENT
# 28     8400200125                              ANCHORAGE MUSEUM
# ...           ...                                           ...
# 33030  8405600191                         TETON SCIENCE SCHOOLS
# 33053  8405600088      WESTON COUNTY MUSEUM DISTRICT FOUNDATION
# 33054  8405600156                    WIND RIVER HERITAGE CENTER
# 33068  8405600061                          WYOMING STATE MUSEUM
# 33070  8405600137                 WYOMING TRANSPORTATION MUSEUM
#
#                                               Legal Name  \
# 6      ALASKA JEWISH HISTORICAL MUSEUM AND CULTURAL C...
# 8           ALASKA MASONIC LIBRARY AND MUSEUM FOUNDATION
# ...
